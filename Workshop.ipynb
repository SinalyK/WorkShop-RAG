# %% [markdown]
# # **Build a simple RAG-powered agent**

# %% [markdown]
# - ## **Introduction to Retrieval-Augmented Generation (RAG)**
#   - ### RAG Concept
#       Le RAG (Retrieval-Augmented Generation) est un paradigme où un modèle de langue ne se base pas seulement sur sa mémoire interne, mais va d’abord récupérer des documents pertinents dans une base de connaissances externe, puis utilise ces documents comme contexte pour générer une réponse plus précise et justifiée.
#       L’idée est de combiner les forces de deux mondes : la recherche d’information (retrieval) pour trouver des faits à jour / spécifiques, et la génération de texte (generation) pour produire une réponse fluide, structurée et dans la bonne langue ou le bon style.
#
#       Dans une pipeline RAG classique, le flux ressemble à :
#
#      1. L’utilisateur pose une question (query).
#
#      2. La question est convertie en vecteur, puis on récupère les documents les plus proches dans un index (vector store).
#
#      3. Les documents récupérés sont concaténés à la requête dans un prompt envoyé au LLM.
#
#      4. Le LLM génère une réponse en s’appuyant sur ces documents, souvent avec la possibilité de citer les sources.

# %% [markdown]
# ## Lib Import

# %%
import json
import os
import re
import textwrap
import traceback
from logging import Logger
from typing import Any, Dict, List, Optional, TypedDict

import backoff
import chromadb
import numpy as np
from dotenv import load_dotenv
from google.api_core.exceptions import ResourceExhausted
from IPython.display import Markdown, display
from langchain_chroma import Chroma
from langchain_classic.chains.query_constructor.schema import AttributeInfo
from langchain_classic.retrievers.self_query.base import SelfQueryRetriever
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.language_models.chat_models import BaseChatModel
from langchain_core.messages import AIMessage, BaseMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.tools import BaseTool
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langgraph.graph import END, StateGraph
from pydantic import BaseModel, Field
from sentence_transformers import CrossEncoder, SentenceTransformer
from termcolor import colored  # pip install termcolor
from app import verbose_context, fillful_data, system_cot,system_tot
from app.agent import ReActAgent

load_dotenv(override = True)
logger = Logger(__name__)

# %% [markdown]
# ## Document Load and Split
#
# ### Objectif de cette étape
#
# Avant de créer des embeddings et de faire du RAG, il faut transformer les fichiers bruts (PDF, Markdown, HTML, TXT, etc.) en petits morceaux de texte homogènes appelés *chunks*.
# L’étape **Document load and split** sert donc à :
# - charger les documents sources dans un format unifié (par exemple une liste de `Document` avec `page_content` + `metadata`) ;
# - découper ces documents en segments de taille raisonnable pour l’indexation et le RAG.
#
# ---
#
# ### 1. Document Loading (chargement des documents)
#
# - On lit les fichiers depuis un dossier (`data/`, `docs/`, etc.).
# - On utilise des *document loaders* adaptés au type de fichier : PDF loader, Text loader, Web loader, etc.
# - Chaque fichier devient un ou plusieurs objets `Document` qui contiennent :
#   - le texte (`page_content`) ;
#   - des métadonnées (nom du fichier, page, titre, type de document, etc.).
#
# Points importants :
# - Cette étape est **indépendante du modèle** : l’objectif est juste d’obtenir du texte propre et structuré.
# - Les **métadonnées** serviront plus tard pour :
#   - filtrer lors du retrieval ;
#   - afficher la source dans la réponse (par exemple : “extrait de `doc_X.pdf`, page 5”).
#
# ---
#
# ### 2. Splitting / Chunking des documents
#
# Après le chargement, on *split* les documents en chunks pour deux raisons principales :
# - respecter les **limites de contexte** des modèles (éviter d’envoyer un document de 100 pages d’un coup) ;
# - améliorer la **précision du retrieval** en indexant des morceaux ciblés (paragraphes ou sections) plutôt que des chapitres entiers.
#
# Le *chunking* consiste donc à découper les documents en petits morceaux avant de créer les embeddings.
# Un bon chunking améliore fortement la qualité du retrieval et évite les contextes trop longs ou hors sujet.
#
# #### Taille de chunk
#
# - Choix typique : entre **200 et 1000 tokens / caractères** par chunk, selon le type de contenu.
# - Plus le chunk est **court** :
#   - plus il est précis ;
#   - mais il contient moins de contexte.
# - Plus le chunk est **long** :
#   - plus il contient de contexte ;
#   - mais le signal utile est dilué.
#
# #### Overlap (chevauchement)
#
# - On ajoute un **chevauchement** (par exemple 10–20 % de la taille) entre deux chunks consécutifs pour éviter de couper une idée importante exactement à la limite.
# - Exemple : `chunk_size = 500`, `overlap = 100`
#   → le chunk 2 commence **100 caractères avant** la fin du chunk 1.
#
# #### Text splitter utilisé
#
# - On peut utiliser un splitter de type **`RecursiveCharacterTextSplitter`** qui essaie d’abord de couper sur :
#   - les sauts de ligne doubles (`\n\n`) ;
#   - puis les lignes (`\n`) ;
#   - puis les phrases (`.`) ;
#   - puis les caractères,
#   tout en respectant la taille maximale du chunk.
# - On adapte la liste de séparateurs (`\n\n`, `\n`, `.`, ` `, etc.) selon les documents :
#   - markdown ;
#   - code ;
#   - texte libre.
#
# ---
#
# ### Types of Chunking
#
# Quelques stratégies courantes :
#
# #### Chunking par taille fixe (fixed-size)
#
# - On découpe le texte en segments de longueur fixe (par exemple 500 tokens) avec éventuellement un overlap.
# - **Avantage** : très simple à implémenter.
# - **Inconvénient** : peut couper au milieu d’une phrase ou d’une section logique.
#
# #### Chunking basé sur la structure (semantic / section-based)
#
# - On découpe en utilisant la **structure du document** :
#   - titres, sous-titres, paragraphes, sections de code, listes, etc.
# - **Avantage** : chaque chunk correspond à une idée ou une section cohérente.
# - **Inconvénient** : nécessite un pré‑traitement plus avancé (analyse de la structure, parsing du format).
#
# #### Chunking hybride (taille + structure)
#
# - On commence par segmenter selon la **structure** (par exemple par paragraphe ou par section).
# - On re‑découpe les sections trop longues en morceaux de **taille fixe**.
# - C’est souvent un bon compromis entre :
#   - cohérence sémantique ;
#   - respect de la limite de longueur du modèle.
#
# Le choix de la méthode dépend :
# - du type de documents (articles, docs techniques, code, FAQ, slides, etc.) ;
# - de la taille maximale de contexte que le modèle peut accepter.
#
# ---
#
# ### 3. Bonnes pratiques
#
# - **Adapter le chunking au type de document** :
#   - docs techniques / API → chunk par section ou sous‑titre ;
#   - longs articles → chunk par paragraphe avec une taille cible.
# - **Préserver la cohérence sémantique** :
#   - éviter de mélanger dans un même chunk deux sections sans rapport.
# - **Toujours conserver des métadonnées** (source, page, titre, type) pour pouvoir :
#   - filtrer lors du retrieval ;
#   - tracer d’où viennent les informations dans la réponse.

# %%
path = "docs/Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf"
loader = PyPDFLoader(path)

documents = loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0)

chunks = []

for idx, document in enumerate(documents):
    
    chunk_lines = text_splitter.split_text(document.page_content)

    for index, chunk in  enumerate(chunk_lines):
        
        chunks.append({
            "id" : f"page{idx}_chunk{index}",
            "content": chunk,
            "metadata": {
            "title" : "Building Agentic AI Systems Create_intelligent, autonomous AI agents",
            "source": "Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf",
            "page": idx
        }})

# %%
chunks[0]
# Out:
# {'id': 'page1_chunk0',
#  'content': 'Building Agentic AI Systems\nCreate intelligent, autonomous AI agents that can reason, plan, \nand adapt\nAnjanava Biswas\nWrick Talukdar',
#  'metadata': {'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents',
#   'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf',
#   'page': 1}}

# %%
len(chunks)
# Out:
# 1442

# %% [markdown]
# ## SentenceTransformer, Bi-encoder, Cross-encoder and VectorStore (ChromaDB)
#
# ### SentenceTransformer
#
# #### Rôle général
# SentenceTransformer est une famille de modèles qui transforment des phrases, paragraphes ou chunks de documents en vecteurs numériques appelés *embeddings*.
# Deux textes sémantiquement proches produisent des vecteurs proches dans l’espace vectoriel.
#
# #### Utilisation comme Bi-encoder
# En mode **bi-encoder**, le même modèle encode séparément :
# - la requête de l’utilisateur : `q = f(query)` ;
# - chaque chunk de document : `d = f(chunk)`.
#
# On calcule ensuite une mesure de similarité (cosine, produit scalaire, etc.) entre `q` et tous les `d` pour trouver les documents les plus pertinents.
# Ce fonctionnement est :
# - **rapide** (on pré‑calcule les embeddings des documents) ;
# - **scalable** (on peut gérer des milliers ou millions de chunks).
#
# ---
#
# ### Cross-encoder
#
# #### Principe
# Le **cross-encoder** prend en entrée la paire *(requête, document)* en même temps, par exemple sous la forme :
# `[CLS] query [SEP] document [SEP]`
# et produit directement un **score de pertinence**.
#
# #### Rôle dans le RAG
# - Le cross-encoder voit l’interaction fine entre la question et le texte du document.
# - Il est donc **plus précis**, mais aussi **plus coûteux** que le bi-encoder.
# - Stratégie typique :
#   1. Bi-encoder + Chroma récupèrent un top‑k (par ex. 20 chunks).
#   2. Le cross-encoder rerank ces k chunks.
#   3. On garde seulement les meilleurs (par ex. 3–5) pour les envoyer au LLM.
#
# On combine donc :
# - **Bi-encoder (SentenceTransformer)** pour le *retrieval large échelle*.
# - **Cross-encoder** pour le *reranking de haute qualité* sur un petit ensemble de candidats.
#
# ---
#
# ### VectorStore: ChromaDB
#
# #### Rôle de ChromaDB
# ChromaDB est une base de données vectorielle qui stocke les embeddings et permet de faire de la recherche par similarité.
# Chaque entrée dans une collection Chroma contient au minimum :
# - un **embedding** (vecteur du chunk, produit par le bi-encoder / SentenceTransformer) ;
# - le **texte** du chunk (`page_content`) ;
# - des **métadonnées** (source, page, type de document, etc.).
#
# #### Fonctions principales
# - **Indexation** :
#   - Ajouter pour chaque chunk : `(embedding, texte, metadata)` dans une collection Chroma.
# - **Similarity search** :
#   - À partir de l’embedding d’une requête, récupérer les *k* chunks les plus proches (top‑k).
# - **Filtrage par métadonnées** :
#   - Restreindre la recherche à certains documents, types de fichiers, cours, chapitres, etc.
#
# ---
#
# ### Pipeline complet dans le RAG
#
# #### 1. Phase d’indexation (offline)
# 1. Charger les documents (PDF, TXT, Markdown, etc.).
# 2. Les découper en chunks (Document load and split).
# 3. Encoder chaque chunk avec SentenceTransformer (bi-encoder) pour obtenir un embedding.
# 4. Stocker `(embedding, texte du chunk, métadonnées)` dans une collection Chroma.
#
# #### 2. Phase de requête (online)
# 1. L’utilisateur pose une question en langage naturel.
# 2. Encoder la question avec le même SentenceTransformer (bi-encoder) pour obtenir l’embedding de la requête.
# 3. Interroger Chroma pour récupérer les *k* chunks les plus similaires.
# 4. (Optionnel mais recommandé) Utiliser un **cross-encoder** pour reranker ces k chunks et garder les plus pertinents.
# 5. Envoyer ces chunks (rerankés) comme contexte au LLM pour générer la réponse.
#
# #### 3. Phrase de synthèse pour ton cours
# - SentenceTransformer utilisé en mode **bi-encoder** permet de représenter efficacement les documents et les requêtes sous forme de vecteurs.
# - Le **cross-encoder** améliore la qualité en rerankant un petit ensemble de candidats.
# - **ChromaDB** stocke et recherche ces vecteurs pour alimenter la partie *retrieval* du RAG.

# %%
model = SentenceTransformer("distiluse-base-multilingual-cased-v2")

# %%
chroma_client = chromadb.PersistentClient(path="./chroma_store")
collection = chroma_client.get_or_create_collection(name="agentic_collection")

# %%
collection.count()
# Out:
# 1442

# %%
for chunk in chunks:

    collection.add(
        ids=chunk["id"],
        documents=chunk["content"],
        embeddings=model.encode(chunk["content"]),
        metadatas = chunk["metadata"]
    )

# %% [markdown]
# ### Test Bi-encoding

# %%
# test bi encoding

query = "What's the kind of agents ?"
query_embedding = model.encode([query]).tolist()

results = collection.query(
    query_embeddings=query_embedding,
    n_results=2
)

results
# Out:
# {'ids': [['page73_chunk0', 'page155_chunk4']],
#  'embeddings': None,
#  'documents': [['Questions 49\nQuestions\n1. What are the key characteristics of intelligent agents?\n2. What are the main types of architectural patterns for intelligent agents?\n3. How do deliberative and reactive architectures differ in their strengths and weaknesses?\n4. What is a multi-agent system (MAS) and what are its key characteristics?\n5. What are the main interaction mechanisms in MASs?\n6. In what domains are MASs commonly applied?\nAnswers',
#    'while maintaining clear role separation and specialized tool usage for each agent. The following is \nhow you define agents with AutoGen:\n1 flight_agent = AssistantAgent(\n2    name="flight_planner",\n3    model_client=model_client,\n4    tools=[travel_tools.search_flights],']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'page': 73,
# ...

# %% [markdown]
# ### Test Cross Encoding

# %%
# cross encoding

cross_model = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")

# %%
def transforme_docs(candidate_docs):
    candidate_docs_c = []
    for doc in zip(candidate_docs["ids"][0],  candidate_docs["documents"][0], candidate_docs["metadatas"][0]):
        
        candidate_docs_c.append({"id": doc[0],"page_content":doc[1], "metadata": doc[2]})
    
    return candidate_docs_c

# %%
query = "governance system"
query_embedding = model.encode([query]).tolist()

candidate_docs = collection.query(
    query_embeddings=query_embedding,
    n_results=5,
    include  = ["documents", "metadatas"]
)


pairs = [(query, doc) for doc in candidate_docs["documents"][0]]


scores = cross_model.predict(pairs)

# Sort candidates by score
docs = transforme_docs(candidate_docs)
reranked = sorted(zip(docs, scores), key=lambda x: x[1], reverse=True)

print("Final Reranked Results:")
for doc, score in reranked:
    print(f"Score: {score:.4f} | Doc: {doc}")
# Out:
# Final Reranked Results:
# Score: 5.4085 | Doc: {'id': 'page53_chunk0', 'page_content': 'Understanding self-governance, agency, and autonomy 29\nSelf-governance\nAgentic systems are artificial and human systems that possess self-governance, adaptability, and \ninteraction. Self-governance refers to the ability of a system or entity to govern or control itself \nautonomously, without external direction or control. In the context of agentic systems, self-governance \nimplies that the system can make its own decisions, set its own goals, and regulate its behavior based', 'metadata': {'page': 53, 'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents', 'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf'}}
# ...

# %% [markdown]
# ## Self-Retrieval
#
# ### Définition
#
# Le **self-retrieval** (ou self-RAG / self-querying) désigne un schéma où le *modèle lui-même* décide quelles informations aller chercher dans la base de connaissances, et parfois même génère la requête de recherche la plus adaptée.
# Au lieu d’écrire une requête de retrieval “à la main”, on laisse le LLM analyser la question de l’utilisateur et formuler automatiquement une ou plusieurs requêtes pour interroger le vector store.
#
# ---
#
# ### Idée clé
#
# - Le modèle ne fait pas seulement : *“query utilisateur → retrieval → réponse”*.
# - Il peut d’abord **raisonner** sur la question, puis décider :
#   - s’il a besoin de retrieval ou non ;
#   - **quoi** aller chercher (sous-questions, mots-clés, filtres) ;
#   - **où** aller chercher (tel corpus, tel type de document).
#
# Dans ce schéma, le LLM agit un peu comme un moteur de recherche intelligent qui “s’auto‑interroge” avant de répondre.
#
# ---
#
# ### Exemple de fonctionnement
#
# 1. L’utilisateur pose une question complexe.
# 2. Le modèle reformule ou décompose la question en une ou plusieurs requêtes de recherche internes (self-query).
# 3. Ces requêtes sont envoyées au vector store (Chroma) via le retriever.
# 4. Les documents récupérés sont renvoyés au modèle, qui les utilise pour construire la réponse finale.
#
# On peut aussi utiliser le self-retrieval pour :
# - générer dynamiquement des filtres sur les métadonnées (par exemple, “uniquement les documents de 2024”, “cours = RAG”) ;
# - poser plusieurs sous‑questions successives à la base de connaissances avant de répondre.
#
# ---
#
# ### Lien avec ton agent
#
# - Dans un agent ReAct, le self-retrieval apparaît quand le modèle décide tout seul **quand** appeler le tool de retrieval, et **avec quelle requête**.
# - L’agent peut :
#   - analyser la question de l’utilisateur ;
#   - générer une requête optimisée pour le retriever (self-query) ;
#   - éventuellement refaire une deuxième requête si la première ne suffit pas.
#
# On obtient ainsi un système où :
# - le retriever + Chroma fournissent les documents ;
# - mais c’est le modèle (l’agent) qui pilote *intelligemment* le retrieval via self-retrieval.

# %%
# self-retrieving

document_content_description = (
    "Agentic System Book which explains different architectures of AI systems"
)

embedding_func = embedding_function = HuggingFaceEmbeddings(
    model_name="distiluse-base-multilingual-cased-v2"
)

vectorstore = Chroma(
    persist_directory="./chroma_store",
    embedding_function=embedding_function,
    collection_name="agentic_collection",
)

metadata_field_info = [
    AttributeInfo(
        name="content",
        description="Chunk content",
        type="string",
    ),
]

# %%
llm_groq = ChatGroq(model = "openai/gpt-oss-20b")

# %%
self_retriever = SelfQueryRetriever.from_llm(
    llm_groq,
    vectorstore,
    document_content_description,
    metadata_field_info,
)

# %%
self_retriever.invoke("C'est quoi ReAct")
# Out:
# [Document(id='page134_chunk1', metadata={'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents', 'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf', 'page': 134}, page_content='6    base_url = "<api URL>"\n7\n8    params = {\n9        "q": location,\n10        "appid": API_KEY,\n11       "units": "imperial"  # For Fahrenheit\n12  }\n13  response = requests.get(base_url, params=params)\n14  if response.status_code == 200:\n15      data = response.json()\n16      return data\nAt the minimum, the LLM agent requires the tool’s description of what the tool does and what input \nit expects. Y ou can also specify which parameters (in this case, location and date) are mandatory'),
# ...

# %%
documents = self_retriever.invoke("how to build an ia system")

# %%
verbose_context(documents)
# Out:
# > Retrouvé 4 documents:
# --- [Document 1] ------------------------------------------------
# Metadata: {'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents', 'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf', 'page': 268}
#
# Content:
# improving systems. While current AI models excel at narrow tasks, true AGI remains a distant goal,
# requiring a fundamental shift in how machines learn, reason, and interact with the world. When we
# combine AGI with autonomous agents, we create something truly revolutionary – systems  that can
# think deeply while acting independently in the world. These combined systems would make  complex
# decisions on their own, understanding not just the technical aspects but also the social and
# ...
#
#
# --- [Document 2] ------------------------------------------------
# ...

# %%
display(Markdown(llm_groq.invoke(str(fillful_data("How to build an AI agent sysem", system_cot, reranker = False))).content))
# Out:
# > Retrouvé 4 documents:
# --- [Document 1] ------------------------------------------------
# Metadata: {'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents', 'page': 15, 'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf'}
#
# Content:
# generative AI systems 154 System prompts and agent behavior 154
# ...
#
#
# --- [Document 2] ------------------------------------------------
# Metadata: {'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents', 'page': 264, 'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf'}
#
# Content:
# We then explored what makes an AI system agentic – meaning it can act on its own. These systems need
# three key abilities: they must react to their environment, take initiative to reach goals, and work
# well  with other agents. Think of it like teaching a computer to be both independent and a good team
# ...

# %%
display(Markdown(llm_groq.invoke(str(fillful_data("A method of ai agent", system_tot))).content))
# Out:
# > Retrouvé 4 documents:
# --- [Document 1] ------------------------------------------------
# Metadata: {'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents', 'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf', 'page': 253}
#
# Content:
# how agents can creatively solve physical manipulation tasks by drawing on vast knowledge bases.
# Let’s consider a real use case and evaluate how an agentic system may help implement such a system.
# Problem statement Traditional manufacturing cells struggle with product variation and unexpected
# disruptions. Current  systems require extensive reprogramming for new products and can’t effectively
# handle unexpected
# ...
#
#
# --- [Document 2] ------------------------------------------------
# Metadata: {'page': 155, 'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf', 'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents'}
#
# Content:
# ...

# %% [markdown]
# ## Reranker Retrieving
#
# ### Définition
#
# Le **reranker retrieving** est une stratégie en deux étapes où l’on sépare :
# 1. le **retrieval initial** (rapide, souvent avec un bi-encoder + vector store) ;
# 2. le **reranking** (reclassement plus précis) d’un petit nombre de documents candidats avant de les envoyer au LLM.
#
# L’idée est d’obtenir à la fois la **vitesse** du bi-encoder et la **précision** d’un modèle plus puissant (souvent un cross-encoder).
#
# ---
#
# ### Étape 1 : Retrieval initial (bi-encoder + Chroma)
#
# 1. La requête utilisateur est encodée avec le bi-encoder (SentenceTransformer).
# 2. On interroge le vector store (Chroma) avec cet embedding.
# 3. Chroma renvoie un premier **top‑k** de chunks (par exemple 20) classés par similarité.
#
# Ce top‑k est “bon mais imparfait” : il contient en général les bons documents, mais pas toujours dans le meilleur ordre.
#
# ---
#
# ### Étape 2 : Reranking (cross-encoder)
#
# 1. Pour chaque document du top‑k, on forme une paire *(requête, chunk)*.
# 2. On passe cette paire dans un **cross-encoder** qui produit un **score de pertinence** plus fin.
# 3. On trie les k chunks selon ce score et on ne garde que les meilleurs (par exemple top‑3 ou top‑5).
#
# Le cross-encoder :
# - lit en même temps la requête et le chunk ;
# - capture les interactions fines (mots-clés, négations, contexte) ;
# - améliore donc la qualité du classement final.
#
# ---
#
# ### Avantages du reranker retrieving
#
# - **Meilleure précision** : le LLM reçoit les documents les plus pertinents, ce qui réduit le risque d’hallucination ou de réponse hors sujet.
# - **Efficacité** : on ne fait du cross-encoding que sur un petit ensemble (top‑k), donc le coût reste raisonnable.
# - **Complémentarité** :
#   - bi-encoder + Chroma → balayage large, rapide ;
#   - cross-encoder → affinement de haute qualité.
#
# ---
#
# On utilise le **bi-encoder** et Chroma pour récupérer rapidement un ensemble de documents candidats, puis un **cross-encoder** comme *reranker* pour les reclasser et ne garder que les plus pertinents avant de les donner au LLM.

# %%
def transforme_docs(candidate_docs):
    candidate_docs_c = []
    for doc in zip(
        candidate_docs["ids"][0],
        candidate_docs["documents"][0],
        candidate_docs["metadatas"][0],
    ):

        candidate_docs_c.append(
            {"id": doc[0], "page_content": doc[1], "metadata": doc[2]}
        )

    return candidate_docs_c

def reranker_rag(query: str):

    query_embedding = model.encode([query]).tolist()
    
    candidate_docs = collection.query(
        query_embeddings=query_embedding,
        n_results=5,
        include  = ["documents", "metadatas"]
    )


    pairs = [(query, doc) for doc in candidate_docs["documents"][0]]


    scores = cross_model.predict(pairs)

    # Sort candidates by score
    docs = transforme_docs(candidate_docs)
    reranked = sorted(zip(docs, scores), key=lambda x: x[1], reverse=True)


    return reranked

# %%
docs = reranker_rag("How to build an ai agent system")

# %%
docs
# Out:
# [({'id': 'page1_chunk0',
#    'page_content': 'Building Agentic AI Systems\nCreate intelligent, autonomous AI agents that can reason, plan, \nand adapt\nAnjanava Biswas\nWrick Talukdar',
#    'metadata': {'page': 1,
#     'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents',
#     'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf'}},
#   np.float32(5.6163406)),
#  ({'id': 'page264_chunk1',
#    'page_content': 'We then explored what makes an AI system agentic – meaning it can act on its own. These systems need \nthree key abilities: they must react to their environment, take initiative to reach goals, and work well \nwith other agents. Think of it like teaching a computer to be both independent and a good team player.\nThe book then showed us how these agents think and make decisions. They need ways to store \nknowledge, learn from experience, and plan their actions. Just like humans use their memory and',
# ...

# %%
verbose_context(docs)
# Out:
# > Retrouvé 5 documents:
# --- [Document 1] ------------------------------------------------
# Metadata: {'page': 1, 'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents', 'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf'}
#
# Content:
# Building Agentic AI Systems Create intelligent, autonomous AI agents that can reason, plan,  and
# adapt Anjanava Biswas Wrick Talukdar
# ...
#
#
# --- [Document 2] ------------------------------------------------
# Metadata: {'page': 264, 'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf', 'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents'}
#
# Content:
# We then explored what makes an AI system agentic – meaning it can act on its own. These systems need
# three key abilities: they must react to their environment, take initiative to reach goals, and work
# ...

# %%
display(Markdown(llm_groq.invoke(str(fillful_data("How to build an AI agent sysem", system_cot, reranker = True))).content))
# Out:
# > Retrouvé 5 documents:
# --- [Document 1] ------------------------------------------------
# Metadata: {'page': 93, 'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf', 'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents'}
#
# Content:
# Start building agentic AI We have learned quite a lot about the characteristics of intelligent
# agents, how they are built, how they  work with different algorithms, and their essential
# components. It is now time for a gentle introduction  to the world of agentic AI and to start
# building applications using different frameworks. In subsequent chapters of this book, we will make
# extensive use of several open source frameworks. The
# ...
#
#
# --- [Document 2] ------------------------------------------------
# ...

# %% [markdown]
# ## Introduction to Agents
#
# ### ReAct
#
# Un **agent** est un système qui ne se contente pas de répondre en une seule fois, mais qui peut raisonner, appeler des outils externes, observer les résultats, puis continuer son raisonnement avant d’émettre une réponse finale.
# Le paradigme **ReAct** (Reason + Act) formalise ce comportement en alternant des phases de réflexion (*Thought*) et d’action (*Action*).
#
# #### Schéma ReAct typique
#
# - **Thought (raisonnement)**
#   Le modèle réfléchit en langage naturel :
#   “Pour répondre à cette question, il faut d’abord chercher dans la base, puis vérifier la météo, etc.”
#
# - **Action (appel d’outil)**
#   Le modèle choisit un outil (retriever RAG, API web, calcul, base de données…) et l’appelle avec certains arguments.
#
# - **Observation (résultat de l’outil)**
#   Le système récupère la sortie de l’outil et la donne au modèle.
#
# - Puis retour à **Thought**, éventuellement nouvelle **Action**, jusqu’à la **Final Answer**.
#
# #### Intérêt du schéma ReAct
#
# Ce cycle permet à l’agent de :
# - Combiner le RAG (vector store) avec des APIs externes (Tavily, météo, etc.).
# - Décomposer des tâches complexes en sous-tâches successives.
# - Être plus transparent : on peut inspecter les “Thoughts” et les “Actions” dans les logs du notebook.
#
# ---
#
# ### Tools
#
# Les **tools** (outils) sont des fonctions que l’agent peut appeler pour interagir avec le monde extérieur ou avec des systèmes spécialisés.
#
# #### Types de tools en contexte RAG
#
# - **Tool de retrieval (RAG)**
#   - *Description* : interroger un vector store (par exemple Chroma) à partir d’une requête texte pour récupérer les documents les plus pertinents.
#   - *Rôle* : cœur du “R” dans RAG, utilisé quand l’agent a besoin d’informations issues de la base de connaissances locale.
#
# - **Tool de recherche web**
#   - *Description* : interroger un moteur ou une API de recherche pour obtenir des informations à jour.
#   - *Rôle* : utile quand la réponse ne se trouve pas dans la base locale ou concerne l’actualité, des chiffres récents, etc.
#
# - **Tool d’API métier (ex : météo, base de données interne)**
#   - *Exemple* : appeler l’API OpenWeather pour récupérer la météo d’une ville donnée, ou une API interne pour les stocks produits.
#   - *Rôle* : connecter l’agent à des données structurées ou temps réel.
#
# - **Tools utilitaires**
#   - *Exemples* : calculs, parsing, conversion de formats, accès fichiers, etc.
#   - *Rôle* : automatiser des sous-tâches techniques (par exemple, convertir une date, analyser un JSON).
#
# #### Comment l’agent utilise les tools
#
# Dans le notebook, tu peux expliquer que :
# - Un agent ReAct “voit” une **liste de tools disponibles**, avec pour chacun une description textuelle (ce qu’il fait, ses paramètres).
# - En fonction de la question de l’utilisateur et de son raisonnement interne, l’agent choisit dynamiquement **quel tool appeler, dans quel ordre et combien de fois**.
# - Le **RAG** devient alors un *tool parmi d’autres* dans l’écosystème de l’agent.

# %% [markdown]
# ### Web search Engine

# %%
def get_tavily_engine():
    from langchain_tavily import TavilySearch
    try:
        return TavilySearch(
            max_results=5,
            topic="general",
        )
    except Exception as e:
        print(e)
        return object()

# %%
tavily = get_tavily_engine()

tavily.invoke("African Cup of Nations 2025 at Morocco")
# Out:
# {'query': 'African Cup of Nations 2025 at Morocco',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.instagram.com/p/DSQMXElDafO/',
#    'title': 'Africa cup of nations Morocco 2025 . Together - Instagram',
#    'content': 'The African Cup 2025 in Morocco: A Celebration of Football and Culture',
#    'score': 0.99992573,
#    'raw_content': None},
#   {'url': 'https://www.instagram.com/reel/DSNZaa7DPMr/',
#    'title': 'Africa Cup of Nations 2025: Morocco Kick-Off in Fès on December 23',
#    'content': 'Morocco is set to host the Africa Cup of Nations 2025, a highly anticipated football tournament that brings together top African teams to',
#    'score': 0.99992156,
#    'raw_content': None},
#   {'url': 'https://story-lecarrousel-rabat.com/african-cup-of-nations-2025/',
#    'title': 'African Cup of Nations 2025: Key Dates, Teams, and Morocco Venues',
# ...

# %%
self_retriever.invoke("agent")
# Out:
# [Document(id='page109_chunk3', metadata={'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf', 'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents', 'page': 109}, page_content='an agent. Y ou may provide the agent with tools to accomplish and complete the task. Here’s a sample \ncode snippet where we define agents for our example with CrewAI:\n1  from crewai import Agent\n2\n3  preference_agent = Agent(\n4      name="Preference Agent",\n5      role="Travel destination recommender",\n6      goal="Provide the best travel destination based on user\n             preferences and weights.",\n7      backstory="An AI travel expert adept at understanding user'),
# ...

# %% [markdown]
# ### Weather API from RapidAPI

# %%
import requests

def get_weather_by_city(city: str):
    
    try: 
        url = "https://open-weather13.p.rapidapi.com/city"
        
        querystring = {"city":city,"lang":"EN"}
        
        headers = {
        	"x-rapidapi-key": "ac0480af20msh9d1cb0e36f13761p1a3064jsnd45e9104368d",
        	"x-rapidapi-host": "open-weather13.p.rapidapi.com"
        }
        
        response = requests.get(url, headers=headers, params=querystring)
    
        return response.json()
    except Exception as e:
        return e

# %%
get_weather_by_city("Berkane")
# Out:
# {'message': 'You have exceeded the MONTHLY quota for Requests on your current plan, BASIC. Upgrade your plan at https://rapidapi.com/worldapi/api/open-weather13'}

# %%
def fillful_data(query):

    if not query:
        return "query must be a string"

    context = reranker_rag(query)
    return context

# %%
fillful_data("agent")
# Out:
# [({'id': 'page109_chunk3',
#    'page_content': 'an agent. Y ou may provide the agent with tools to accomplish and complete the task. Here’s a sample \ncode snippet where we define agents for our example with CrewAI:\n1  from crewai import Agent\n2\n3  preference_agent = Agent(\n4      name="Preference Agent",\n5      role="Travel destination recommender",\n6      goal="Provide the best travel destination based on user\n             preferences and weights.",\n7      backstory="An AI travel expert adept at understanding user',
#    'metadata': {'page': 109,
#     'title': 'Building Agentic AI Systems Create_intelligent, autonomous AI agents',
#     'source': 'Building_Agentic_AI_Systems_Create_intelligent,_autonomous_AI_agents.pdf'}},
#   np.float32(5.876337)),
#  ({'id': 'page155_chunk4',
# ...

# %%
### Tools
from langchain_core.tools import Tool

retriever_tool = Tool(
    name="Retriever",
    func=fullfill_data,
    description="Retrieve book action relevant to the query from Chroma vectorstore.",
)



search_tool = Tool(
    name = "TavilySearch",
    func = get_tavily_engine().invoke,
    description = "Web search engine for retrieving information on internet."
)


weather_tool = Tool(
    name = "WeatherAction",
    func = get_weather_by_city,
    description = ""
)

# %%
weather_tool.func("Oujda")
# Out:
# {'coord': {'lon': -1.9076, 'lat': 34.6805},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 59.63,
#   'feels_like': 57.54,
#   'temp_min': 59.63,
#   'temp_max': 59.63,
#   'pressure': 1013,
#   'humidity': 48,
#   'sea_level': 1013,
#   'grnd_level': 935},
#  'visibility': 10000,
#  'wind': {'speed': 18.41, 'deg': 250},
#  'clouds': {'all': 40},
#  'dt': 1765813972,
#  'sys': {'type': 1,
#   'id': 2400,
#   'country': 'MA',
#   'sunrise': 1765782453,
#   'sunset': 1765817892},
#  'timezone': 3600,
#  'id': 2540483,
#  'name': 'Oujda',
#  'cod': 200}

# %%
llm = ChatGoogleGenerativeAI(model = "gemini-2.0-flash")

# %%
tools = [retriever_tool, search_tool, weather_tool]

# %%
agent = ReActAgent(llm = llm_groq , tools = tools)

# %%
await agent.arun("decris moi le livre dans ton retriever")
# Out:
# history:  []
# node plan executed with success
# history:  []
# node plan executed with success
# history:  []
# node plan executed with success
# history:  []
# node plan executed with success
# history:  []
# node plan executed with success
# history:  []
# node plan executed with success
# history:  []
# node plan executed with success
# {'question': 'decris moi le livre dans ton retriever',
# ...
